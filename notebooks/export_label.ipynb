# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from models import multiscale_model as multiscale
from models import model
from models import track_model
from src.utils import visualize_detection_video, visualize_tracking_video, visualize_detection_image

# %%
# model_path = "checkpoints/deyolo-2.pt"
# model_path = "checkpoints/IR/yolov8n/best.pt"
model_path = "checkpoints/RGB/yolov8n2/best.pt"
video_path = """C:\\Users\\phamd\\Downloads\\vipcup-20250711T154912Z-1-001\\test_img_video\\RGB\\V_BIRD_00564.mp4"""
video_name = os.path.basename(video_path).split('.')[0]
output_dir = f"annotations/{video_name}"

# %%
def save_tracking_annotations_yolo(
    video_path: str,
    tracking_frames: list,
    output_dir: str,
    class_mapping: dict = None
):
    """
    Save tracking annotations in YOLO txt format
    
    Args:
        video_path: Path to the video file
        tracking_frames: List of tracking results from video_track()
        output_dir: Directory to save the annotation files
        class_mapping: Optional dict to map class_id to class names
    """
    
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    # Get video info
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    
    # Group tracking results by frame
    frame_annotations = {}
    for track in tracking_frames:
        frame_idx = track['frame_idx']
        if frame_idx not in frame_annotations:
            frame_annotations[frame_idx] = []
        frame_annotations[frame_idx].append(track)
    
    # Generate YOLO format annotations for each frame
    for frame_idx in range(total_frames):
        # Create filename for this frame
        frame_filename = f"frame_{frame_idx:06d}.txt"
        frame_path = os.path.join(output_dir, frame_filename)
        
        # Write annotations for this frame
        with open(frame_path, 'w') as f:
            if frame_idx in frame_annotations:
                for track in frame_annotations[frame_idx]:
                    # Extract bbox coordinates
                    x1, y1, x2, y2 = track['bbox']
                    
                    # Convert to YOLO format (normalized center_x, center_y, width, height)
                    center_x = (x1 + x2) / 2 / frame_width
                    center_y = (y1 + y2) / 2 / frame_height
                    width = (x2 - x1) / frame_width
                    height = (y2 - y1) / frame_height
                    
                    # Get class ID
                    class_id = int(track['label'])
                    
                    # Write YOLO format line: class_id center_x center_y width height
                    f.write(f"{class_id} {center_x:.6f} {center_y:.6f} {width:.6f} {height:.6f}\n")
    
    print(f"Saved {len(frame_annotations)} frames of annotations to {output_dir}")
    
    # Save class mapping if provided
    if class_mapping:
        classes_path = os.path.join(output_dir, "classes.txt")
        with open(classes_path, 'w') as f:
            for class_id, class_name in sorted(class_mapping.items()):
                f.write(f"{class_name}\n")
        print(f"Saved class mapping to {classes_path}")

def save_tracking_annotations_yolo_with_tracking_id(
    video_path: str,
    tracking_frames: list,
    output_dir: str,
    class_mapping: dict = None
):
    """
    Save tracking annotations in YOLO txt format with tracking IDs
    Format: class_id center_x center_y width height track_id
    """
    
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    # Get video info
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    
    # Group tracking results by frame
    frame_annotations = {}
    for track in tracking_frames:
        frame_idx = track['frame_idx']
        if frame_idx not in frame_annotations:
            frame_annotations[frame_idx] = []
        frame_annotations[frame_idx].append(track)
    
    # Generate YOLO format annotations for each frame
    for frame_idx in range(total_frames):
        # Create filename for this frame
        frame_filename = f"frame_{frame_idx:06d}.txt"
        frame_path = os.path.join(output_dir, frame_filename)
        
        # Write annotations for this frame
        with open(frame_path, 'w') as f:
            if frame_idx in frame_annotations:
                for track in frame_annotations[frame_idx]:
                    # Extract bbox coordinates
                    x1, y1, x2, y2 = track['bbox']
                    
                    # Convert to YOLO format (normalized center_x, center_y, width, height)
                    center_x = (x1 + x2) / 2 / frame_width
                    center_y = (y1 + y2) / 2 / frame_height
                    width = (x2 - x1) / frame_width
                    height = (y2 - y1) / frame_height
                    
                    # Get class ID and track ID
                    class_id = int(track['label'])
                    track_id = track['track_id']
                    
                    # Write YOLO format line with track ID: class_id center_x center_y width height track_id
                    f.write(f"{class_id} {center_x:.6f} {center_y:.6f} {width:.6f} {height:.6f} {track_id}\n")
    
    print(f"Saved {len(frame_annotations)} frames of annotations with tracking IDs to {output_dir}")
    
    # Save class mapping if provided
    if class_mapping:
        classes_path = os.path.join(output_dir, "classes.txt")
        with open(classes_path, 'w') as f:
            for class_id, class_name in sorted(class_mapping.items()):
                f.write(f"{class_name}\n")
        print(f"Saved class mapping to {classes_path}")

# %%
class_mapping = {
    0: "BIRD",  # or whatever your class names are
    1: "DRONE",
}

# Create tracking model and get results
multiscale_model = multiscale.DetectionModel(
    model_path,
    conf_threshold=0.2,
    iou_threshold=0.1,
    device="cuda",
)

multiscale_track_model = track_model.TrackingModel(multiscale_model)
multiscale_track_outputs = multiscale_track_model.video_track(video_path)

# Save annotations in YOLO format


# Save standard YOLO format (without tracking IDs)
save_tracking_annotations_yolo(
    video_path=video_path,
    tracking_frames=multiscale_track_outputs,
    output_dir=output_dir,
    class_mapping=class_mapping
)

# Or save with tracking IDs
# save_tracking_annotations_yolo_with_tracking_id(
#     video_path=video_path,
#     tracking_frames=multiscale_track_outputs,
#     output_dir=f"{output_dir}_with_ids",
#     class_mapping=class_mapping
# )
# Out:
# Frame 0: Detected 4 objects
# Frame 1: Detected 4 objects
# Frame 1: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 2: Detected 5 objects
# Frame 2: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 3: Detected 4 objects
# Frame 3: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 4: Detected 4 objects
# Frame 4: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 5: Detected 5 objects
# Frame 5: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 6: Detected 4 objects
# Frame 6: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 7: Detected 3 objects
# Frame 7: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 8: Detected 4 objects
# Frame 8: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 9: Detected 4 objects
# Frame 9: Active: 1, Lost: 2, Recovered: 1, Valid: 1
# Frame 10: Detected 4 objects
# Frame 10: Active: 2, Lost: 0, Recovered: 1, Valid: 0
# Frame 11: Detected 4 objects
# Frame 11: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 12: Detected 4 objects
# Frame 12: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 13: Detected 4 objects
# Frame 13: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 14: Detected 4 objects
# Frame 14: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 15: Detected 4 objects
# Frame 15: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 16: Detected 4 objects
# Frame 16: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 17: Detected 4 objects
# Frame 17: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 18: Detected 4 objects
# Frame 18: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 19: Detected 5 objects
# Frame 19: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 20: Detected 5 objects
# Frame 20: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 21: Detected 5 objects
# Frame 21: Active: 2, Lost: 2, Recovered: 2, Valid: 2
# Frame 22: Detected 5 objects
# Frame 22: Active: 2, Lost: 2, Recovered: 2, Valid: 2
# Frame 23: Detected 5 objects
# Frame 23: Active: 3, Lost: 1, Recovered: 1, Valid: 0
# Frame 24: Detected 5 objects
# Frame 24: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 25: Detected 5 objects
# Frame 25: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 26: Detected 4 objects
# Frame 26: Active: 2, Lost: 1, Recovered: 0, Valid: 0
# Frame 27: Detected 4 objects
# Frame 27: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 28: Detected 4 objects
# Frame 28: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 29: Detected 4 objects
# Frame 29: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 30: Detected 4 objects
# Frame 30: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 31: Detected 4 objects
# Frame 31: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 32: Detected 5 objects
# Frame 32: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 33: Detected 5 objects
# Frame 33: Active: 3, Lost: 0, Recovered: 1, Valid: 0
# Frame 34: Detected 5 objects
# Frame 34: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 35: Detected 5 objects
# Frame 35: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 36: Detected 5 objects
# Frame 36: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 37: Detected 5 objects
# Frame 37: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 38: Detected 4 objects
# Frame 38: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 39: Detected 4 objects
# Frame 39: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 40: Detected 4 objects
# Frame 40: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 41: Detected 4 objects
# Frame 41: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 42: Detected 4 objects
# Frame 42: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 43: Detected 4 objects
# Frame 43: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 44: Detected 4 objects
# Frame 44: Active: 3, Lost: 0, Recovered: 1, Valid: 1
# Frame 45: Detected 4 objects
# Frame 45: Active: 1, Lost: 2, Recovered: 0, Valid: 0
# Frame 46: Detected 4 objects
# Frame 46: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 47: Detected 4 objects
# Frame 47: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 48: Detected 4 objects
# Frame 48: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 49: Detected 4 objects
# Frame 49: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 50: Detected 5 objects
# Frame 50: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 51: Detected 5 objects
# Frame 51: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 52: Detected 4 objects
# Frame 52: Active: 2, Lost: 1, Recovered: 0, Valid: 0
# Frame 53: Detected 4 objects
# Frame 53: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 54: Detected 4 objects
# Frame 54: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 55: Detected 4 objects
# Frame 55: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 56: Detected 4 objects
# Frame 56: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 57: Detected 3 objects
# Frame 57: Active: 3, Lost: 0, Recovered: 1, Valid: 0
# Frame 58: Detected 4 objects
# Frame 58: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 59: Detected 4 objects
# Frame 59: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 60: Detected 4 objects
# Frame 60: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 61: Detected 4 objects
# Frame 61: Active: 3, Lost: 1, Recovered: 0, Valid: 0
# Frame 62: Detected 4 objects
# Frame 62: Active: 3, Lost: 1, Recovered: 0, Valid: 0
# Frame 63: Detected 5 objects
# Frame 63: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 64: Detected 4 objects
# Frame 64: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 65: Detected 4 objects
# Frame 65: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 66: Detected 4 objects
# Frame 66: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 67: Detected 4 objects
# Frame 67: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 68: Detected 4 objects
# Frame 68: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 69: Detected 4 objects
# Frame 69: Active: 3, Lost: 1, Recovered: 0, Valid: 0
# Frame 70: Detected 4 objects
# Frame 70: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 71: Detected 4 objects
# Frame 71: Active: 4, Lost: 1, Recovered: 1, Valid: 0
# Frame 72: Detected 5 objects
# Frame 72: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 73: Detected 5 objects
# Frame 73: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 74: Detected 5 objects
# Frame 74: Active: 3, Lost: 1, Recovered: 1, Valid: 1
# Frame 75: Detected 4 objects
# Frame 75: Active: 2, Lost: 3, Recovered: 1, Valid: 1
# Frame 76: Detected 4 objects
# Frame 76: Active: 0, Lost: 3, Recovered: 1, Valid: 1
# Frame 77: Detected 4 objects
# Frame 77: Active: 1, Lost: 0, Recovered: 1, Valid: 0
# Frame 78: Detected 5 objects
# Frame 78: Active: 1, Lost: 0, Recovered: 0, Valid: 0
# Frame 79: Detected 5 objects
# Frame 79: Active: 1, Lost: 0, Recovered: 0, Valid: 0
# Frame 80: Detected 4 objects
# Frame 80: Active: 0, Lost: 1, Recovered: 1, Valid: 1
# Frame 81: Detected 5 objects
# Frame 81: Active: 2, Lost: 1, Recovered: 1, Valid: 0
# Frame 82: Detected 5 objects
# Frame 82: Active: 2, Lost: 1, Recovered: 1, Valid: 0
# Frame 83: Detected 5 objects
# Frame 83: Active: 1, Lost: 1, Recovered: 0, Valid: 0
# Frame 84: Detected 5 objects
# Frame 84: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 85: Detected 5 objects
# Frame 85: Active: 2, Lost: 1, Recovered: 1, Valid: 0
# Frame 86: Detected 5 objects
# Frame 86: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 87: Detected 5 objects
# Frame 87: Active: 2, Lost: 1, Recovered: 1, Valid: 0
# Frame 88: Detected 5 objects
# Frame 88: Active: 2, Lost: 1, Recovered: 1, Valid: 0
# Frame 89: Detected 5 objects
# Frame 89: Active: 2, Lost: 1, Recovered: 1, Valid: 0
# Frame 90: Detected 5 objects
# Frame 90: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 91: Detected 6 objects
# Frame 91: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 92: Detected 6 objects
# Frame 92: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 93: Detected 6 objects
# Frame 93: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 94: Detected 6 objects
# Frame 94: Active: 3, Lost: 1, Recovered: 1, Valid: 0
# Frame 95: Detected 5 objects
# Frame 95: Active: 3, Lost: 1, Recovered: 1, Valid: 0
# Frame 96: Detected 5 objects
# Frame 96: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 97: Detected 5 objects
# Frame 97: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 98: Detected 5 objects
# Frame 98: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 99: Detected 5 objects
# Frame 99: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 100: Detected 5 objects
# Frame 100: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 101: Detected 5 objects
# Frame 101: Active: 3, Lost: 0, Recovered: 1, Valid: 0
# Frame 102: Detected 5 objects
# Frame 102: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 103: Detected 5 objects
# Frame 103: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 104: Detected 5 objects
# Frame 104: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 105: Detected 5 objects
# Frame 105: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 106: Detected 6 objects
# Frame 106: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 107: Detected 5 objects
# Frame 107: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 108: Detected 5 objects
# Frame 108: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 109: Detected 5 objects
# Frame 109: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 110: Detected 5 objects
# Frame 110: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 111: Detected 5 objects
# Frame 111: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 112: Detected 4 objects
# Frame 112: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 113: Detected 5 objects
# Frame 113: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 114: Detected 5 objects
# Frame 114: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 115: Detected 4 objects
# Frame 115: Active: 3, Lost: 0, Recovered: 1, Valid: 0
# Frame 116: Detected 4 objects
# Frame 116: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 117: Detected 4 objects
# Frame 117: Active: 3, Lost: 1, Recovered: 1, Valid: 1
# Frame 118: Detected 4 objects
# Frame 118: Active: 3, Lost: 1, Recovered: 1, Valid: 1
# Frame 119: Detected 3 objects
# Frame 119: Active: 3, Lost: 1, Recovered: 0, Valid: 0
# Frame 120: Detected 3 objects
# Frame 120: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 121: Detected 4 objects
# Frame 121: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 122: Detected 4 objects
# Frame 122: Active: 2, Lost: 1, Recovered: 0, Valid: 0
# Frame 123: Detected 4 objects
# Frame 123: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 124: Detected 5 objects
# Frame 124: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 125: Detected 5 objects
# Frame 125: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 126: Detected 5 objects
# Frame 126: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 127: Detected 4 objects
# Frame 127: Active: 1, Lost: 1, Recovered: 1, Valid: 1
# Frame 128: Detected 3 objects
# Frame 128: Active: 1, Lost: 1, Recovered: 1, Valid: 1
# Frame 129: Detected 3 objects
# Frame 129: Active: 2, Lost: 1, Recovered: 0, Valid: 0
# Frame 130: Detected 3 objects
# Frame 130: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 131: Detected 3 objects
# Frame 131: Active: 2, Lost: 0, Recovered: 0, Valid: 0
# Frame 132: Detected 3 objects
# Frame 132: Active: 1, Lost: 1, Recovered: 1, Valid: 1
# Frame 133: Detected 4 objects
# Frame 133: Active: 2, Lost: 0, Recovered: 1, Valid: 0
# Frame 134: Detected 5 objects
# Frame 134: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 135: Detected 5 objects
# Frame 135: Active: 2, Lost: 1, Recovered: 0, Valid: 0
# Frame 136: Detected 5 objects
# Frame 136: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 137: Detected 5 objects
# Frame 137: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 138: Detected 5 objects
# Frame 138: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 139: Detected 4 objects
# Frame 139: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 140: Detected 4 objects
# Frame 140: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 141: Detected 4 objects
# Frame 141: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 142: Detected 4 objects
# Frame 142: Active: 4, Lost: 0, Recovered: 0, Valid: 0
# Frame 143: Detected 4 objects
# Frame 143: Active: 2, Lost: 2, Recovered: 2, Valid: 2
# Frame 144: Detected 3 objects
# Frame 144: Active: 2, Lost: 2, Recovered: 3, Valid: 1
# Frame 145: Detected 5 objects
# Frame 145: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Frame 146: Detected 5 objects
# Frame 146: Active: 3, Lost: 0, Recovered: 1, Valid: 0
# Frame 147: Detected 5 objects
# Frame 147: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 148: Detected 5 objects
# Frame 148: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 149: Detected 5 objects
# Frame 149: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 150: Detected 4 objects
# Frame 150: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 151: Detected 5 objects
# Frame 151: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 152: Detected 5 objects
# Frame 152: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 153: Detected 5 objects
# Frame 153: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 154: Detected 5 objects
# Frame 154: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 155: Detected 4 objects
# Frame 155: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 156: Detected 4 objects
# Frame 156: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 157: Detected 4 objects
# Frame 157: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 158: Detected 3 objects
# Frame 158: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 159: Detected 3 objects
# Frame 159: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 160: Detected 3 objects
# Frame 160: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 161: Detected 3 objects
# Frame 161: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 162: Detected 3 objects
# Frame 162: Active: 3, Lost: 0, Recovered: 0, Valid: 0
# Frame 163: Detected 3 objects
# Frame 163: Active: 2, Lost: 1, Recovered: 1, Valid: 1
# Saved 164 frames of annotations to annotations/V_BIRD_00564
# Saved class mapping to annotations/V_BIRD_00564\classes.txt
